# %%
from portfolio_optimizer.widgets_notebook import *
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import pandas as pd
from pandas.tseries.offsets import *
import portfolio_optimizer.port as prt
import numpy as np
import matplotlib.pyplot as plt
import portfolio_optimizer

# %%
class PortData():
    def __init__(self,dic):
        self.Widgets = dic
        self.init_port = dic['data']['init_port']
        self.share_balance = np.array(list(dic['data']['init_port'].values()))[np.newaxis,:]
        self.shares = dic['data']['init_port'].keys()
        self.start = pd.to_datetime(dic['data']['start_date'])
        self.end = pd.to_datetime(dic['data']['end_date'])
        self.strategies = dic['strategies']
        self.params = dic['backtest']['params']
        self.load_data()
        self.V0()
        self.rf=0.001
    def V0(self):
        start = self.start
        while (start in self.data.index) == False:
            start += DateOffset(days=1)
            
        
        self.V = [self.data.loc[start][x]*self.init_port[x] for x in self.init_port]
    
    def load_data(self):
        csv = os.path.join(portfolio_optimizer.__path__[0],'Daily_closing_prices.csv')
        data = pd.read_csv(csv,index_col='Date')
        data.index = pd.to_datetime(data.index)
        data = data.drop(['YHOO'],axis=1)
        data = data[list(self.init_port.keys())]
        returns = data.shift(1)/data-1
        self.data = data
        self.returns = returns
        pass

# %% [markdown]
# ## Intro
# The portfolio_optimizer.port script contains the implementation of several classes for each type of portfolio strategy (eg. mamx sharpe, buy and hold). It also containt an implementation of a class to generate the efficient frontier.<br><br>
# The portfolio_optimizer.widgets_notebook is an implementation to collect data on an interactive format using widgets.

# %% [markdown]
# ## Building a Portfolio Object
# The PortData class stores relevant data from the widgets object. This object should be updated to include other means to load data such as quandl. Here it is uploading a toy dataset. The method V0 is run at initialization to calculate the portfolio initial value. Currently, the code is running with a symbolic interest rate data, but it should be update in the future to include scarping from the appropriate website.

# %% [markdown]
# ## The Evaluate class allows to test multiple strategies in one batch
#
# Summary is a table that reports the changes in portfolio value and available cash over time.

# %%
def evaluate(Iport):
    
    kwargs = {'stocks':Iport.shares,'share_balance':Iport.share_balance,'V':Iport.V}
    
    strategies = {'strat_buy_and_hold':prt.strat_buy_and_hold(**kwargs,buy_h=1),
                    'strat_equally_weighted':prt.strat_equally_weighted(**kwargs),
                    'strat_max_Sharpe':prt.strat_max_Sharpe(**kwargs),
                    'strat_max_Sharpe_eff':prt.strat_max_Sharpe(**kwargs,use_eff=1),
                    'strat_min_variance':prt.strat_min_variance(**kwargs)}
    value = []
    strat = []
    daily_returns = {}
    summary = {}
    for x in Iport.strategies:
        print(x)
        print('Portfolio initial value: {}'.format(np.sum(Iport.V)))

        port = strategies[x]
        W,log = backtest(port,Iport.data,Iport.start,Iport.end,Iport.params,Iport.rf)
        
        value.append(float((port.V_hist[-1:]-port.V_hist[0])/port.V_hist[0]))
        strat.append(x)
        daily_returns[x]=port.dailyV
        summary[x]=log['value'].map('${:,.2f}'.format)
    summary['beg'] = log['beg']
    summary['end'] = log['end']
    summary = pd.DataFrame(summary)

    total_ret = pd.DataFrame(data=value,index=strat,columns=['return'])
    total_ret.T.plot(title='portfolio total return',table=True,kind='bar',alpha=0.5,sort_columns=True,use_index=False)
    day_ret = pd.DataFrame(daily_returns,columns=daily_returns.keys(),index=port.time)
    day_ret.plot()
    print(summary)
    print(total_ret)
    pass

# %% [markdown]
# ## The Backtest class will backtest a portfolio object
#
# The class takes the object and a rebalancing frequency and run a loop to collect all intermediate values and optimal allocation.
#
# ### get_data()
# Calculates the variance-covariance matrix Q and the return vector mu for each iteration

# %%
def get_data(data):
    returns = data.shift(1)/data-1
    Q = np.array(prt.cov(returns))
    mu = np.array(returns.mean())
    return Q,mu

# %% [markdown]
# ### backtest()

# %%
'''OUTPUT: W,log'''
''''Step forward'''
'''Algorithim for slicing the data on a rolling window basis - coupled with OLS and Hedging classes'''
def backtest(obj,d1,start,end,params,rf=0.001):
    log = {'beg':[],'end':[],'value':[],'cash':[]}
    index=[start]
    back= params['back']
    forward = params['forward']
    
    offset = BMonthEnd()
    start = offset.rollback(start)
    
    t0 = start+DateOffset(**back)
    roll_forward = DateOffset(**forward)
    dates = pd.date_range(start+roll_forward,end+roll_forward,freq=roll_forward)
    
    W = []
    for i in dates:
                      
        data_window = d1.loc[:i].copy()
          
        Q,mu = get_data(data_window)
        p = d1.loc[i-roll_forward:i].copy()

  
        obj.update_V(p,rf)
        
        w = obj.optimize(Q,mu) 

        obj.update_cash_account()
             
        log['beg'].append(i-roll_forward)
        log['end'].append(i)
        index.append(i)

    log['value'] = obj.V_hist[1:]

    
    if obj.buy_h==1:
        log['cash']= np.zeros(len(log['end']))
    else:
        log['cash'] = obj.cash_hist

    log = pd.DataFrame(log,columns=log.keys())
    real_ret = (obj.V_hist[-1:]-obj.V_hist[0])/obj.V_hist[0]
    print("\n Total portfolio Valorization: {}".format(real_ret))
    W = np.vstack(obj.W)
    
    W = pd.DataFrame(data=W,columns=obj.stocks)
    plt.figure()
    W.plot(kind='bar',title="Dynamic allocation "+obj.method,stacked=True).legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

 
    return W,log

# %% [markdown]
# # Example 1: Portfolio Optimization

# %% [markdown]
# Currently there are 5 strategies implemented in the class port:
#
# -  'strat_buy_and_hold':prt.strat_buy_and_hold(**kwargs,buy_h=1)
# -  'strat_equally_weighted':prt.strat_equally_weighted(**kwargs),
# -  'strat_max_Sharpe':prt.strat_max_Sharpe(**kwargs)
# -  'strat_max_Sharpe_eff':prt.strat_max_Sharpe(**kwargs,use_eff=1)
# -  'strat_min_variance':prt.strat_min_variance(**kwargs)
#
# The keyword can be extracted from the portData class or inserted directly. They are:<br>
# kwargs:{
# 'stocks':Iport.shares,'share_balance':Iport.share_balance,'V':Iport.V}
#
# Each portfolio class has an optimization method that requires a variance-covariance matrix (Q) and a return vector(mu).

# %% [markdown]
# ### Load data:

# %%
stocks = ['AAPL', 'AMD', 'AMZN', 'BAC', 'BK', 
          'CRAY', 'CSCO', 'F', 'GOOG', 'HOG', 
          'HPQ', 'IBM', 'INTC', 'MS', 'MSFT', 
          'NVDA', 'SNE', 'T', 'VZ']

csv = os.path.join(portfolio_optimizer.__path__[0],'Daily_closing_prices.csv')
data = pd.read_csv(csv,index_col='Date')
data.index = pd.to_datetime(data.index)
data = data.drop(['YHOO'],axis=1)
data = data[list(stocks)]
returns = data.shift(1)/data-1

# %%
from portfolio_optimizer.widgets_notebook import *
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import pandas as pd
from pandas.tseries.offsets import *
import portfolio_optimizer.port as prt
import numpy as np
import matplotlib.pyplot as plt
import portfolio_optimizer

'''Variance-covariance matrix and return vector'''
X = returns[1:]
Q = X.T.dot(X)/(len(X)+1)
mu = X.mean()

'''Setup data'''

stocks = ['AAPL', 'AMD', 'AMZN', 'BAC', 'BK', 
          'CRAY', 'CSCO', 'F', 'GOOG', 'HOG', 
          'HPQ', 'IBM', 'INTC', 'MS', 'MSFT', 
          'NVDA', 'SNE', 'T', 'VZ']

share_balance = np.array([3000.0, 0, 0, 0, 0, 2000.0, 0, 
                 950.0, 0, 0, 0, 1500.0, 0, 0, 
                 5000.0, 1001.0, 0, 0, 2000.0])

V = 1000002.119999

kwargs={
'stocks':stocks,'share_balance':share_balance,'V':V}

Portfolio = prt.strat_max_Sharpe(**kwargs)
w = Portfolio.optimize(Q,mu) #optimal allocation


'''OUTPUT'''
'''Plot optimal allocation'''

plt.figure(figsize=(14,6))
plt.title('Maximum Sharpe')
plt.plot(X.columns,w)

Portfolio = prt.strat_equally_weighted(**kwargs)
w = Portfolio.optimize(Q,mu)

'''Plot optimal allocation'''
plt.figure(figsize=(14,6))
plt.title('Equally weighted')
plt.plot(X.columns,w)

# %% [markdown]
# # Example 2: Backtest one strategy

# %% [markdown]
# Here we use the portfolio class ad input for the backtest class. To run the backtest, one need to set up the data time range (start and end dates) and a parameters argument that will define the rolling window scheme:
#
# param{
# back:{'months':0}
# forward:{'months':2}
# }
#
# This means that the analysis will start from the start date, the first rebalancing will occur 2 months after it. The back parameters will determine how many months before the start date should be included on the first optimization.
#
# The forward parameter will define the rebalancing strategy. The key is the time unit (months or days) and the value is the period. (eg months:5 - rebalancing after 5 months)
#
# The window is setup to exeute rebalancing at the last business day of the month and the analsys will always begin from the last business day of the month before the start date.

# %%
stocks = ['AAPL', 'AMD', 'AMZN', 'BAC', 'BK', 
          'CRAY', 'CSCO', 'F', 'GOOG', 'HOG', 
          'HPQ', 'IBM', 'INTC', 'MS', 'MSFT', 
          'NVDA', 'SNE', 'T', 'VZ']

share_balance = np.array([3000.0, 0, 0, 0, 0, 2000.0, 0, 
                 950.0, 0, 0, 0, 1500.0, 0, 0, 
                 5000.0, 1001.0, 0, 0, 2000.0])

V = 1000002.119999

kwargs={
'stocks':stocks,'share_balance':share_balance,'V':V}

params = {'back': {'months': 0}, 'forward': {'months': 2}}

start = pd.to_datetime('2015-01-01')
end = pd.to_datetime('2016-12-31')

Portfolio = prt.strat_equally_weighted(**kwargs)

backtest(Portfolio,data,start,end,params,rf=0.001)
# Out:
#  Total portfolio Valorization: [0.40837722]
# (        AAPL       AMD      AMZN       BAC        BK      CRAY      CSCO  \
#  0   0.009182  0.379809  0.003096  0.074702  0.030169  0.039523  0.040017
#  1   0.008001  0.453124  0.002427  0.066869  0.024457  0.036193  0.035681
#  2   0.008422  0.432989  0.002429  0.061419  0.024873  0.035273  0.037799
#  3   0.007861  0.481465  0.001712  0.054451  0.021906  0.042887  0.034257
#  4   0.008369  0.458128  0.001627  0.057788  0.023191  0.044340  0.034018
#  5   0.010626  0.379142  0.001675  0.066390  0.027633  0.034730  0.041628
#  6   0.009501  0.444653  0.001651  0.072479  0.025483  0.021531  0.034861
#  7   0.012769  0.335706  0.001989  0.081933  0.029809  0.030730  0.043332
#  8   0.013787  0.252480  0.001812  0.101770  0.035109  0.045206  0.046510
#  9   0.014402  0.201119  0.001988  0.097693  0.037750  0.066369  0.049193
#  10  0.013230  0.209277  0.001922  0.090323  0.034623  0.072231  0.049232
# ...

# %% [markdown]
# # Example 3: Widgets and Multiple strategies analysis

# %% [markdown]
# The class widgets is designed to work on jupyer notebook to make it easier to prepare the basic data to enter on the evaluate class. The evaluate class will run multiple backtests and provide data to compare the choosen strategies.
#
# The starting point for multi strategy analysis is a dictionary file of the following form:

# %% [markdown]
# {'backtest': {'params': {'back': {'months': 0}, 'forward': {'months': 2}},
#   'plot_eff': Checkbox(value=False, description='Check me'),
#   'rf': 0.0001},
#  'data': {'data_source': 'toy',
#   'end_date': '2016-12-31',
#   'init_port': {'AAPL': 3000.0,
#    'AMD': 0,
#    'AMZN': 0,
#    'BAC': 0,
#    'BK': 0,
#    'CRAY': 2000.0,
#    'CSCO': 0,
#    'F': 950.0,
#    'GOOG': 0,
#    'HOG': 0,
#    'HPQ': 0,
#    'IBM': 1500.0,
#    'INTC': 0,
#    'MS': 0,
#    'MSFT': 5000.0,
#    'NVDA': 1001.0,
#    'SNE': 0,
#    'T': 0,
#    'VZ': 2000.0},
#   'start_date': '2015-01-01'},
#  'strategies': ('strat_buy_and_hold',
#   'strat_equally_weighted',
#   'strat_max_Sharpe',
#   'strat_max_Sharpe_eff',
#   'strat_min_variance')}

# %% [markdown]
# One could use any text editor to build a json file and have it uploaded as dic to use as an input rather than using the widgets class. The dictionary is wraped with the class PortData() that will pack all necessary information for the evaluate class.

# %%
Widgets = PortWidgets()
# Out:
# SelectMultiple(description='Stocks', index=(0,), options=('AAPL', 'AMD', 'AMZN', 'BAC', 'BK', 'CRAY', 'CSCO', 'F', 'GOOG', 'HOG', 'HPQ', 'IBM', 'INTC', 'MS', 'MSFT', 'NVDA', 'SNE', 'T', 'VZ'), rows=15, value=('AAPL',))
# SelectMultiple(description='Strategies', index=(0, 1, 2, 3, 4), options=('strat_buy_and_hold', 'strat_equally_weighted', 'strat_max_Sharpe', 'strat_max_Sharpe_eff', 'strat_min_variance'), value=('strat_buy_and_hold', 'strat_equally_weighted', 'strat_max_Sharpe', 'strat_max_Sharpe_eff', 'strat_min_variance'))
# DatePicker(value=datetime.date(2015, 1, 1), description='Start_date')
# DatePicker(value=datetime.date(2016, 12, 31), description='End_date')
# ...
# Checkbox(value=False, description='Check me')
# Button(description='set weights!', style=ButtonStyle())
# Button(description='Build!', style=ButtonStyle())
# FloatText(value=10.0, description='AAPL')
# FloatText(value=10.0, description='CRAY')
# FloatText(value=10.0, description='F')
# ...

# %%
Iport = PortData(Widgets.dic)
evaluate(Iport)
# Out:
# strat_buy_and_hold
# Portfolio initial value: 4788.7999
#
#  Total portfolio Valorization: [0.97650772]
# strat_equally_weighted
# Portfolio initial value: 4788.7999
#
#  Total portfolio Valorization: [-0.54322794]
# strat_max_Sharpe
# Portfolio initial value: 4788.7999
#
#  Total portfolio Valorization: [0.65122798]
# strat_max_Sharpe_eff
# Portfolio initial value: 4788.7999
#
#  Total portfolio Valorization: [0.06725906]
# strat_min_variance
# Portfolio initial value: 4788.7999
#
#  Total portfolio Valorization: [-0.65493651]
#           beg        end strat_buy_and_hold strat_equally_weighted  \
# 0  2014-12-28 2015-02-28          $5,666.80              $5,666.80
# 1  2015-02-28 2015-04-28          $6,205.90              $4,351.55
# 2  2015-04-28 2015-06-28          $6,277.10              $4,294.54
# 3  2015-06-28 2015-08-28          $6,901.80              $3,952.62
# 4  2015-08-28 2015-10-28          $7,989.00              $3,778.60
# ...
